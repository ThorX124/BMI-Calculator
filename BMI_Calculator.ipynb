# %% [markdown]
# <a href="https://colab.research.google.com/github/ThorX124/BMI-Calculator/blob/main/BMI_Calculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#BMI Calculator

weight= int(input("Please input your weight in kgs: "))           #Casting String Input to a int
height= float(input("Please input your height in meters: "))      #Casting String Input to a float
height2= height*height
BMI= weight/height2

print('Your approximate BMI is: ', BMI)
# Out:
# Please input your weight in kgs: 60
# Please input your height in meters: 1.8
# Your approximate BMI is:  18.51851851851852

# %% [markdown]
# # **SMIT ASSIGNMENT 1**
# ## Program a BMI Calculator.
# #### This is the very first assignment that I've ever completed. It is a program that first gets input by using `input()` function, but it takes string type inputs, so I casted the input to `int` and `float` accordingly.
#
# #### After that I created a `height2= height*height` as it is required for the formula of BMI that was then declared as `BMI= weight/height2`.
# #### And then finally printed it.

# %%
#BMI Calculator Advanced

print('Do you want to enter your weight in Kilograms or Pounds? (Write 1 for Kilos and 2 for Pounds as your answer) ')
Answer = int(input())

if Answer == 1:
    weight= int(input("Please input your weight in kgs: "))           #Casting String Input to a int
    height= float(input("Please input your height in meters: "))      #Casting String Input to a float
    height2= height*height
    BMI= weight/height2

    print('Your approximate BMI is: ', BMI)

    if BMI < 18.5:
      print('You are underweight')

    elif BMI < 25:
      print('You are normal')

    elif BMI < 30:
      print('You are overweight')

    else:
      print('You are obese')

elif Answer == 2:
    weight= int(input("Please input your weight in lbs: "))           #Casting String Input to a int
    height= float(input("Please input your height in feet: "))      #Casting String Input to a float
    height2= height*12
    height3= height2*height2
    BMI= weight/height3
    BMIr= BMI*703

    print('Your approximate BMI is: ', BMIr)

    if BMIr < 18.5:
      print('You are underweight')

    elif BMIr < 25:
      print('You are normal')

    elif BMIr < 30:
      print('You are overweight')

    else:
      print('You are obese')

else:
    print('Invalid Input')
# Out:
# Do you want to enter your weight in Kilograms or Pounds? (Write 1 for Kilos and 2 for Pounds as your answer)
# 2
# Please input your weight in lbs: 200
# Please input your height in feet: 6
# Your approximate BMI is:  27.12191358024691
# You are overweight

# %% [markdown]
# ##This Second code block was an adventure thats all I can say and I can't believe that i wrote that much code with my hands...I am Happy 🙂
